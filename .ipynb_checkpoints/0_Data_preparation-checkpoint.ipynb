# %% [markdown]
# # Import dataset
# ---

# %%
# Import packages
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf
from pandas_profiling import ProfileReport
import seaborn as sns

# %% [markdown]
# ## Function to obtain data set from zip link

# %%
def zip2df(link):
    zip_path = tf.keras.utils.get_file(origin=link, fname=link.split('/')[-1], extract=True)
    csv_path = zip_path.replace('zip','csv')
    print(csv_path)
    df = pd.read_csv(csv_path)
    return df

# %% [markdown]
# ## Crash data

# %%
link_crash='https://github.com/duonghung86/Fatality-crashes/raw/master/Data/extract_2018_20191217230653_crash_20190601-20191130Texas.zip'
df_crash=zip2df(link_crash)
df_crash.tail()
# Out:
# C:\Users\Duong Hung\.keras\datasets\extract_2018_20191217230653_crash_20190601-20191130Texas.csv

# %% [markdown]
# ## Person data

# %%
link_person='https://github.com/duonghung86/Fatality-crashes/raw/master/Data/extract_2018_20191217230653_primaryperson_20190601-20191130Texas.zip'
df_person=zip2df(link_person)
df_person.tail()

# %% [markdown]
# ## Unit data

# %%
link_unit='https://github.com/duonghung86/Fatality-crashes/raw/master/Data/extract_2018_20191217230653_unit_20190601-20191130Texas.zip'
df_unit=zip2df(link_unit)
df_unit.tail()

# %% [markdown]
# # Features filtering

# %% [markdown]
# ## Person data

# %%
df_person.shape

# %%
# Percentage of missing values for each feature
mvr=df_person.isna().sum()/len(df_person.Crash_ID)
valid_feat=mvr[mvr<0.2].index
print(len(valid_feat))
valid_feat

# %%
df_person=df_person[valid_feat].copy()
df_person.head()

# %% [markdown]
# Remove unrelated variables:
# - Driver name
# - Injury information
# - Dirver lisence information
# - Alcohol or Drug test type
# - Solicitation

# %%
keeps=['Crash_ID', 'Unit_Nbr', 'Prsn_Nbr', 'Prsn_Type_ID',
       'Prsn_Occpnt_Pos_ID', 'Prsn_Injry_Sev_ID', 'Prsn_Age', 'Prsn_Ethnicity_ID', 'Prsn_Gndr_ID',
       'Prsn_Ejct_ID', 'Prsn_Rest_ID', 'Prsn_Airbag_ID', 'Prsn_Helmet_ID',
       'Prsn_Drg_Rslt_ID']
df_person=df_person[keeps].copy()
print(df_person.shape)
df_person.head()
# Out:
# (597983, 14)
#    Crash_ID  Unit_Nbr  Prsn_Nbr  Prsn_Type_ID  Prsn_Occpnt_Pos_ID  \
# 0  15657177         1         1             1                   1
# 1  16473665         1         1             1                   1
# 2  16473665         2         1             1                   1
# 3  16871051         1         1             1                   1
# 4  16871051         3         1             1                   1
#
#    Prsn_Injry_Sev_ID  Prsn_Age  Prsn_Ethnicity_ID  Prsn_Gndr_ID  Prsn_Ejct_ID  \
# 0                  0      16.0                2.0             1             1
# 1                  5      48.0                1.0             1             1
# 2                  2      58.0                1.0             2             1
# 3                  5      68.0                1.0             1             1
# 4                  5      67.0                1.0             2             1
#
#    Prsn_Rest_ID  Prsn_Airbag_ID  Prsn_Helmet_ID  Prsn_Drg_Rslt_ID
# 0             1               8              97                97
# 1             1               2              97                97
# 2             1               3              97                 1
# 3             1               2              97                97
# 4             1               4              97                97

# %%
df_person.describe()
# Out:
#            Crash_ID       Unit_Nbr  Prsn_Nbr   Prsn_Type_ID  \
# count  5.979830e+05  597983.000000  597983.0  597983.000000
# mean   1.727792e+07       1.546788       1.0       1.389038
# std    9.514967e+04       0.684930       0.0       5.669102
# min    1.565718e+07       1.000000       1.0       1.000000
# 25%    1.719668e+07       1.000000       1.0       1.000000
# 50%    1.727875e+07       1.000000       1.0       1.000000
# 75%    1.735971e+07       2.000000       1.0       1.000000
# max    1.746129e+07      12.000000       1.0      99.000000
#
#        Prsn_Occpnt_Pos_ID  Prsn_Injry_Sev_ID       Prsn_Age  \
# count       597983.000000      597983.000000  541806.000000
# mean             1.228889           4.111120      39.043049
# std              2.100483           1.646568      16.494515
# min              1.000000           0.000000       0.000000
# 25%              1.000000           3.000000      25.000000
# 50%              1.000000           5.000000      36.000000
# 75%              1.000000           5.000000      51.000000
# max             98.000000           5.000000     119.000000
#
#        Prsn_Ethnicity_ID   Prsn_Gndr_ID   Prsn_Ejct_ID   Prsn_Rest_ID  \
# count      595119.000000  597983.000000  597983.000000  597983.000000
# mean            1.722106       1.315788       1.382268       2.427109
# std             1.039173       0.606981       1.135102       3.295887
# min             0.000000       0.000000       1.000000       1.000000
# 25%             1.000000       1.000000       1.000000       1.000000
# 50%             2.000000       1.000000       1.000000       1.000000
# 75%             2.000000       2.000000       1.000000       1.000000
# max             6.000000       2.000000       5.000000      11.000000
#
#        Prsn_Airbag_ID  Prsn_Helmet_ID  Prsn_Drg_Rslt_ID
# count   597983.000000   597983.000000     597983.000000
# mean         2.261757       96.065798         96.234134
# std          1.623532        9.320402          8.571866
# min          0.000000        1.000000          0.000000
# 25%          2.000000       97.000000         97.000000
# 50%          2.000000       97.000000         97.000000
# 75%          2.000000       97.000000         97.000000
# max          8.000000       97.000000         97.000000

# %%
## as Prsn_Nbr contains 1 unique values, we will remove it
df_person.drop(columns=['Prsn_Nbr'], inplace = True)

# %%
# remove all null rows
df_person.dropna(inplace=True)

# %%
plt.figure(figsize=(20,4))
df_person.drop(columns=['Crash_ID']).boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Based on the above figure we should remove some outliers

# %%
df_person.Prsn_Drg_Rslt_ID.hist()
# Out:
# <AxesSubplot:>

# %%
# remove outliers

#Person type values are between 1 and 6
df_person = df_person[(df_person.Prsn_Type_ID>0) & (df_person.Prsn_Type_ID<7)].copy()
df_person.shape
# Out:
# (538438, 13)

# %%
df_person.head()
# Out:
#    Crash_ID  Unit_Nbr  Prsn_Type_ID  Prsn_Occpnt_Pos_ID  Prsn_Injry_Sev_ID  \
# 0  15657177         1             1                   1                  0
# 1  16473665         1             1                   1                  5
# 2  16473665         2             1                   1                  2
# 3  16871051         1             1                   1                  5
# 4  16871051         3             1                   1                  5
#
#    Prsn_Age  Prsn_Ethnicity_ID  Prsn_Gndr_ID  Prsn_Ejct_ID  Prsn_Rest_ID  \
# 0      16.0                2.0             1             1             1
# 1      48.0                1.0             1             1             1
# 2      58.0                1.0             2             1             1
# 3      68.0                1.0             1             1             1
# 4      67.0                1.0             2             1             1
#
#    Prsn_Airbag_ID  Prsn_Helmet_ID  Prsn_Drg_Rslt_ID
# 0               8              97                97
# 1               2              97                97
# 2               3              97                 1
# 3               2              97                97
# 4               4              97                97

# %%
#Occupation position are between 1 and 16
df_person = df_person[df_person.Prsn_Occpnt_Pos_ID<17].copy()
df_person.shape
# Out:
# (538438, 13)

# %%
df_person.head()
# Out:
#    Crash_ID  Unit_Nbr  Prsn_Type_ID  Prsn_Occpnt_Pos_ID  Prsn_Injry_Sev_ID  \
# 0  15657177         1             1                   1                  0
# 1  16473665         1             1                   1                  5
# 2  16473665         2             1                   1                  2
# 3  16871051         1             1                   1                  5
# 4  16871051         3             1                   1                  5
#
#    Prsn_Age  Prsn_Ethnicity_ID  Prsn_Gndr_ID  Prsn_Ejct_ID  Prsn_Rest_ID  \
# 0      16.0                2.0             1             1             1
# 1      48.0                1.0             1             1             1
# 2      58.0                1.0             2             1             1
# 3      68.0                1.0             1             1             1
# 4      67.0                1.0             2             1             1
#
#    Prsn_Airbag_ID  Prsn_Helmet_ID  Prsn_Drg_Rslt_ID
# 0               8              97                97
# 1               2              97                97
# 2               3              97                 1
# 3               2              97                97
# 4               4              97                97

# %%
#Injury severity are between 1 and 5
df_person = df_person[(df_person.Prsn_Injry_Sev_ID>0) & (df_person.Prsn_Injry_Sev_ID<7)].copy()
print(df_person.shape)
df_person.head()
# Out:
# (530918, 13)
#    Crash_ID  Unit_Nbr  Prsn_Type_ID  Prsn_Occpnt_Pos_ID  Prsn_Injry_Sev_ID  \
# 1  16473665         1             1                   1                  5
# 2  16473665         2             1                   1                  2
# 3  16871051         1             1                   1                  5
# 4  16871051         3             1                   1                  5
# 5  17055798         1             1                   1                  5
#
#    Prsn_Age  Prsn_Ethnicity_ID  Prsn_Gndr_ID  Prsn_Ejct_ID  Prsn_Rest_ID  \
# 1      48.0                1.0             1             1             1
# 2      58.0                1.0             2             1             1
# 3      68.0                1.0             1             1             1
# 4      67.0                1.0             2             1             1
# 5      36.0                2.0             2             1             1
#
#    Prsn_Airbag_ID  Prsn_Helmet_ID  Prsn_Drg_Rslt_ID
# 1               2              97                97
# 2               3              97                 1
# 3               2              97                97
# 4               4              97                97
# 5               2              97                97

# %%
df_person.Prsn_Helmet_ID.value_counts()
# Out:
# 97    525204
# 4       2808
# 1       1097
# 2        971
# 3        492
# 5        346
# Name: Prsn_Helmet_ID, dtype: int64

# %%
df_final=df_person.copy()

# %% [markdown]
# ## Crash data

# %%
df_crash.shape
# Out:
# (324117, 173)

# %%
# Percentage of missing values for each feature
mvr=df_crash.isna().sum()/len(df_crash.Crash_ID)
valid_feat=mvr[mvr<0.2].index
print(len(valid_feat))
valid_feat
# Out:
# 74
# Index(['Crash_ID', 'Crash_Fatal_Fl', 'Cmv_Involv_Fl', 'Schl_Bus_Fl',
#        'Rr_Relat_Fl', 'Medical_Advisory_Fl', 'Amend_Supp_Fl',
#        'Active_School_Zone_Fl', 'Crash_Date', 'Crash_Time', 'Case_ID',
#        'Rpt_CRIS_Cnty_ID', 'Rpt_City_ID', 'Rpt_Outside_City_Limit_Fl',
#        'Thousand_Damage_Fl', 'Rpt_Rdwy_Sys_ID', 'Rpt_Road_Part_ID',
#        'Rpt_Block_Num', 'Rpt_Street_Name', 'Private_Dr_Fl', 'Toll_Road_Fl',
#        'Crash_Speed_Limit', 'Road_Constr_Zone_Fl', 'Road_Constr_Zone_Wrkr_Fl',
#        'At_Intrsct_Fl', 'Rpt_Sec_Rdwy_Sys_ID', 'Rpt_Sec_Road_Part_ID',
#        'Rpt_Sec_Street_Name', 'Wthr_Cond_ID', 'Light_Cond_ID', 'Entr_Road_ID',
#        'Road_Algn_ID', 'Surf_Cond_ID', 'Traffic_Cntl_ID',
#        'Investigat_Notify_Time', 'Investigat_Notify_Meth',
#        'Investigat_Arrv_Time', 'Report_Date', 'Investigat_Comp_Fl',
#        'Investigator_Name', 'ID_Number', 'ORI_Number', 'Investigat_Agency_ID',
#        'Bridge_Detail_ID', 'Harm_Evnt_ID', 'Intrsct_Relat_ID', 'FHE_Collsn_ID',
#        'Obj_Struck_ID', 'Othr_Factr_ID', 'Road_Part_Adj_ID', 'Road_Cls_ID',
#        'Road_Relat_ID', 'Phys_Featr_1_ID', 'Phys_Featr_2_ID', 'Cnty_ID',
#        'City_ID', 'Latitude', 'Longitude', 'Street_Name', 'Txdot_Rptable_Fl',
#        'Onsys_Fl', 'Rural_Fl', 'Crash_Sev_ID', 'Pop_Group_ID', 'Located_Fl',
#        'Day_of_Week', 'Sus_Serious_Injry_Cnt', 'Nonincap_Injry_Cnt',
#        'Poss_Injry_Cnt', 'Non_Injry_Cnt', 'Unkn_Injry_Cnt', 'Tot_Injry_Cnt',
#        'Death_Cnt', 'Investigat_Service_ID'],
#       dtype='object')

# %% [markdown]
# Keep related variables:
# - Crash ID
# - Time
# - Road,weather information
# - Location information

# %%
keepsc=['Crash_ID', 'Crash_Date', 'Crash_Time','Day_of_Week', 
       'Rpt_Rdwy_Sys_ID', 'Rpt_Road_Part_ID', 'Toll_Road_Fl', 'Crash_Speed_Limit',
       'Road_Constr_Zone_Fl', 'Road_Constr_Zone_Wrkr_Fl', 'At_Intrsct_Fl',
       'Wthr_Cond_ID', 'Light_Cond_ID', 
       'Road_Algn_ID', 'Surf_Cond_ID', 'Traffic_Cntl_ID','Latitude', 'Longitude', 'Pop_Group_ID'
       ]

# %%
df_crash=df_crash[keepsc].copy()
df_crash.head()
# Out:
#    Crash_ID  Crash_Date Crash_Time Day_of_Week  Rpt_Rdwy_Sys_ID  \
# 0  15657177  06/02/2019   12:58 PM         SUN               15
# 1  16473665  06/15/2019   11:00 AM         SAT                2
# 2  16871051  06/12/2019   09:53 AM         WED                2
# 3  17055798  06/04/2019   03:07 PM         TUE               19
# 4  17099571  06/01/2019   01:00 AM         SAT               19
#
#    Rpt_Road_Part_ID Toll_Road_Fl  Crash_Speed_Limit Road_Constr_Zone_Fl  \
# 0                 1            N                 40                   N
# 1                 1            N                 35                   N
# 2                 1            N                 45                   N
# 3                 1            N                 35                   N
# 4                 1            N                 30                   N
#
#   Road_Constr_Zone_Wrkr_Fl At_Intrsct_Fl  Wthr_Cond_ID  Light_Cond_ID  \
# 0                        N             N            11              4
# 1                        N             Y            11              1
# 2                        N             N            11              1
# 3                        N             N            12              1
# 4                        N             N            11              3
#
#    Road_Algn_ID  Surf_Cond_ID  Traffic_Cntl_ID   Latitude  Longitude  \
# 0             4             1                1  32.280231 -97.746616
# 1             3             1                5  30.660685 -93.893906
# 2             1             1               20  33.203920 -96.596654
# 3             2             1               10  29.792394 -95.746539
# 4             1             1               11  32.797549 -96.699878
#
#    Pop_Group_ID
# 0           NaN
# 1           1.0
# 2           8.0
# 3           0.0
# 4           9.0

# %%
for var in keepsc:
    if var.find('Fl')!=-1:
        print(var)
        df_crash[var] = np.where(df_crash[var]=='Y',1,0)
# Out:
# Toll_Road_Fl
# Road_Constr_Zone_Fl
# Road_Constr_Zone_Wrkr_Fl
# At_Intrsct_Fl

# %%
df_crash.describe()
# Out:
#            Crash_ID  Rpt_Rdwy_Sys_ID  Rpt_Road_Part_ID   Toll_Road_Fl  \
# count  3.241170e+05    324117.000000     324117.000000  324117.000000
# mean   1.727797e+07        11.559829          1.415211       0.016275
# std    9.543925e+04         7.898879          1.340898       0.126531
# min    1.565718e+07         1.000000          1.000000       0.000000
# 25%    1.719629e+07         3.000000          1.000000       0.000000
# 50%    1.727870e+07        15.000000          1.000000       0.000000
# 75%    1.736023e+07        19.000000          1.000000       0.000000
# max    1.746129e+07        19.000000          7.000000       1.000000
#
#        Crash_Speed_Limit  Road_Constr_Zone_Fl  Road_Constr_Zone_Wrkr_Fl  \
# count      324117.000000        324117.000000             324117.000000
# mean           40.696258             0.042750                  0.013924
# std            18.631591             0.202293                  0.117176
# min            -1.000000             0.000000                  0.000000
# 25%            30.000000             0.000000                  0.000000
# 50%            40.000000             0.000000                  0.000000
# 75%            55.000000             0.000000                  0.000000
# max            85.000000             1.000000                  1.000000
#
#        At_Intrsct_Fl   Wthr_Cond_ID  Light_Cond_ID   Road_Algn_ID  \
# count  324117.000000  324117.000000  324117.000000  324117.000000
# mean        0.291892      10.368170       1.776871       1.422212
# std         0.454633       2.575779       1.311285       1.147850
# min         0.000000       0.000000       0.000000       1.000000
# 25%         0.000000      11.000000       1.000000       1.000000
# 50%         0.000000      11.000000       1.000000       1.000000
# 75%         1.000000      11.000000       3.000000       1.000000
# max         1.000000      12.000000       8.000000       8.000000
#
#         Surf_Cond_ID  Traffic_Cntl_ID       Latitude      Longitude  \
# count  324117.000000    324117.000000  287847.000000  287847.000000
# mean        1.146571        11.098613      30.811151     -97.430597
# std         0.673947         7.864144       1.904964       2.502731
# min         0.000000         1.000000      25.862659    -106.625904
# 25%         1.000000         5.000000      29.653902     -98.277897
# 50%         1.000000         9.000000      30.243530     -96.992473
# 75%         1.000000        20.000000      32.688839     -95.524747
# max        10.000000        21.000000      36.500007     -93.543413
#
#         Pop_Group_ID
# count  317487.000000
# mean        6.214402
# std         3.419317
# min         0.000000
# 25%         5.000000
# 50%         8.000000
# 75%         9.000000
# max         9.000000

# %%
plt.figure(figsize=(20,4))
df_crash.drop(columns=['Crash_ID']).boxplot()
# Out:
# <AxesSubplot:>

# %%
df_final=df_final.merge(df_crash,left_on='Crash_ID', right_on='Crash_ID')
df_final.tail()
# Out:
#         Crash_ID  Unit_Nbr  Prsn_Type_ID  Prsn_Occpnt_Pos_ID  \
# 530913  17460970         1             1                   1
# 530914  17461030         1             1                   1
# 530915  17461030         2             1                   1
# 530916  17461292         1             1                   1
# 530917  17461292         2             1                   1
#
#         Prsn_Injry_Sev_ID  Prsn_Age  Prsn_Ethnicity_ID  Prsn_Gndr_ID  \
# 530913                  5      68.0                1.0             1
# 530914                  5      44.0                1.0             1
# 530915                  3      57.0                3.0             2
# 530916                  5      16.0                1.0             2
# 530917                  5      16.0                1.0             1
#
#         Prsn_Ejct_ID  Prsn_Rest_ID  ...  Road_Constr_Zone_Wrkr_Fl  \
# 530913             1             1  ...                         0
# 530914             1             1  ...                         0
# 530915             1             1  ...                         0
# 530916             1             1  ...                         0
# 530917             1             1  ...                         0
#
#         At_Intrsct_Fl  Wthr_Cond_ID Light_Cond_ID Road_Algn_ID Surf_Cond_ID  \
# 530913              0            11             6            1            0
# 530914              0            11             1            1            1
# 530915              0            11             1            1            1
# 530916              1            11             1            1            1
# 530917              1            11             1            1            1
#
#         Traffic_Cntl_ID   Latitude  Longitude  Pop_Group_ID
# 530913                1  28.954878 -97.987513           0.0
# 530914                8  32.756880 -94.354907           1.0
# 530915                8  32.756880 -94.354907           1.0
# 530916                8  31.279209 -94.579816           1.0
# 530917                8  31.279209 -94.579816           1.0
#
# [5 rows x 31 columns]

# %%
df_final.shape
# Out:
# (530918, 31)

# %% [markdown]
# ## Unit data

# %%
df_unit.shape
# Out:
# (654542, 100)

# %%
# Percentage of missing values for each feature
mvr=df_unit.isna().sum()/len(df_unit.Crash_ID)
valid_feat=mvr[mvr<0.2].index
print(len(valid_feat))
valid_feat
# Out:
# 39
# Index(['Crash_ID', 'Unit_Nbr', 'Unit_Desc_ID', 'Veh_Parked_Fl', 'Veh_HNR_Fl',
#        'Veh_Lic_State_ID', 'Veh_Lic_Plate_Nbr', 'VIN', 'Veh_Mod_Year',
#        'Veh_Color_ID', 'Veh_Make_ID', 'Veh_Mod_ID', 'Veh_Body_Styl_ID',
#        'Emer_Respndr_Fl', 'Owner_Lessee', 'Ownr_Last_Name', 'Ownr_First_Name',
#        'Ownr_Street_Name', 'Ownr_City_Name', 'Ownr_State_ID', 'Ownr_Zip',
#        'Fin_Resp_Proof_ID', 'Fin_Resp_Type_ID', 'Fin_Resp_Name',
#        'Fin_Resp_Policy_Nbr', 'Veh_Dmag_Area_1_ID', 'Veh_Dmag_Scl_1_ID',
#        'Veh_Inventoried_Fl', 'Veh_Cmv_Fl', 'Contrib_Factr_1_ID',
#        'Veh_Trvl_Dir_ID', 'First_Harm_Evt_Inv_ID', 'Sus_Serious_Injry_Cnt',
#        'Nonincap_Injry_Cnt', 'Poss_Injry_Cnt', 'Non_Injry_Cnt',
#        'Unkn_Injry_Cnt', 'Tot_Injry_Cnt', 'Death_Cnt'],
#       dtype='object')

# %%
keepsu=['Crash_ID', 'Unit_Nbr', 'Unit_Desc_ID', 'Veh_Parked_Fl', 'Veh_HNR_Fl',
       'Veh_Mod_Year','Veh_Color_ID', 'Veh_Make_ID', 'Veh_Mod_ID', 'Veh_Body_Styl_ID',
       ]

# %%
df_unit=df_unit[keepsu].copy()
df_unit.head()
# Out:
#    Crash_ID  Unit_Nbr  Unit_Desc_ID Veh_Parked_Fl Veh_HNR_Fl  Veh_Mod_Year  \
# 0  15657177         1             1             N          N        2005.0
# 1  16473665         1             1             N          N        2002.0
# 2  16473665         2             1             N          N        2012.0
# 3  16871051         1             1             N          N        1996.0
# 4  16871051         2             6           NaN        NaN           NaN
#
#    Veh_Color_ID  Veh_Make_ID  Veh_Mod_ID  Veh_Body_Styl_ID
# 0           9.0        107.0       249.0              69.0
# 1          21.0        107.0       547.0              69.0
# 2          17.0         91.0       629.0              30.0
# 3          21.0        672.0      2103.0              87.0
# 4           NaN          NaN         NaN               NaN

# %%
plt.figure(figsize=(20,4))
df_unit.drop(columns=['Crash_ID']).boxplot()
# Out:
# <AxesSubplot:>

# %%
for var in keepsu:
    if var.find('Fl')!=-1:
        print(var)
        df_unit[var] = np.where(df_unit[var]=='Y',1,0)
# Out:
# Veh_Parked_Fl
# Veh_HNR_Fl

# %%
df_final=df_final.merge(df_unit,left_on=['Crash_ID', 'Unit_Nbr'], right_on=['Crash_ID', 'Unit_Nbr'])
print(df_final.shape)
df_final.tail()
# Out:
# (530918, 39)
#         Crash_ID  Unit_Nbr  Prsn_Type_ID  Prsn_Occpnt_Pos_ID  \
# 530913  17460970         1             1                   1
# 530914  17461030         1             1                   1
# 530915  17461030         2             1                   1
# 530916  17461292         1             1                   1
# 530917  17461292         2             1                   1
#
#         Prsn_Injry_Sev_ID  Prsn_Age  Prsn_Ethnicity_ID  Prsn_Gndr_ID  \
# 530913                  5      68.0                1.0             1
# 530914                  5      44.0                1.0             1
# 530915                  3      57.0                3.0             2
# 530916                  5      16.0                1.0             2
# 530917                  5      16.0                1.0             1
#
#         Prsn_Ejct_ID  Prsn_Rest_ID  ...  Longitude  Pop_Group_ID  \
# 530913             1             1  ... -97.987513           0.0
# 530914             1             1  ... -94.354907           1.0
# 530915             1             1  ... -94.354907           1.0
# 530916             1             1  ... -94.579816           1.0
# 530917             1             1  ... -94.579816           1.0
#
#         Unit_Desc_ID Veh_Parked_Fl Veh_HNR_Fl Veh_Mod_Year  Veh_Color_ID  \
# 530913             1             0          0       2019.0          99.0
# 530914             1             0          0       2009.0           9.0
# 530915             1             0          0       2013.0           2.0
# 530916             1             0          0       2012.0          18.0
# 530917             1             0          0       2004.0          18.0
#
#         Veh_Make_ID  Veh_Mod_ID  Veh_Body_Styl_ID
# 530913         37.0      2324.0             106.0
# 530914        118.0      1104.0             104.0
# 530915         91.0       173.0             104.0
# 530916        107.0      1048.0              69.0
# 530917        107.0      2236.0             106.0
#
# [5 rows x 39 columns]

# %%
df_final.columns
# Out:
# Index(['Crash_ID', 'Unit_Nbr', 'Prsn_Type_ID', 'Prsn_Occpnt_Pos_ID',
#        'Prsn_Injry_Sev_ID', 'Prsn_Age', 'Prsn_Ethnicity_ID', 'Prsn_Gndr_ID',
#        'Prsn_Ejct_ID', 'Prsn_Rest_ID', 'Prsn_Airbag_ID', 'Prsn_Helmet_ID',
#        'Prsn_Drg_Rslt_ID', 'Crash_Date', 'Crash_Time', 'Day_of_Week',
#        'Rpt_Rdwy_Sys_ID', 'Rpt_Road_Part_ID', 'Toll_Road_Fl',
#        'Crash_Speed_Limit', 'Road_Constr_Zone_Fl', 'Road_Constr_Zone_Wrkr_Fl',
#        'At_Intrsct_Fl', 'Wthr_Cond_ID', 'Light_Cond_ID', 'Road_Algn_ID',
#        'Surf_Cond_ID', 'Traffic_Cntl_ID', 'Latitude', 'Longitude',
#        'Pop_Group_ID', 'Unit_Desc_ID', 'Veh_Parked_Fl', 'Veh_HNR_Fl',
#        'Veh_Mod_Year', 'Veh_Color_ID', 'Veh_Make_ID', 'Veh_Mod_ID',
#        'Veh_Body_Styl_ID'],
#       dtype='object')

# %%
df_final.dropna(inplace=True)

# %% [markdown]
# # Mapping the data

# %% [markdown]
# ## Get the list of mapping sheets

# %%
term_link='https://github.com/duonghung86/Fatality-crashes/raw/master/Data/Term.xlsx'
xls = pd.ExcelFile(term_link) # help reduce time when read multiple sheets
sheets=xls.sheet_names

# %%
# Link between feature name and its coding sheet

link_c=pd.read_excel(xls,sheet_name='Crash File Specification',header=6,usecols=['Column Header','Description','Data Values with Valid Years if Applicable'])
link_c.head()
# Out:
#     Column Header                                        Description  \
# 0             NaN                          CR-3 Reported Data Fields
# 1        Crash_ID  Crash ID – System-generated unique identifying...
# 2  Crash_Fatal_Fl  Fatal Crash Identifier - Indicates that the cr...
# 3   Cmv_Involv_Fl                               CMV Crash Identifier
# 4     Schl_Bus_Fl  School Bus Crash Identifier - Indicates whethe...
#
#   Data Values with Valid Years if Applicable
# 0                                        NaN
# 1                                        NaN
# 2                          YES_NO_CHOICE_LKP
# 3                          YES_NO_CHOICE_LKP
# 4                          YES_NO_CHOICE_LKP

# %%
# Link between feature name and its coding sheet
link_p=pd.read_excel(xls,sheet_name='PrimaryPerson File Spec.',header=5,usecols=['Column Header','Description','Data Values with Valid Years if Applicable'])
link_p.head()
# Out:
#         Column Header                                        Description  \
# 0            Crash_ID  Crash ID – System-generated unique identifying...
# 1            Unit_Nbr  Unit number entered on crash report for a unit...
# 2            Prsn_Nbr         Person number captured on the crash report
# 3        Prsn_Type_ID                                        Person Type
# 4  Prsn_Occpnt_Pos_ID  The physical location of an occupant in, on, o...
#
#   Data Values with Valid Years if Applicable
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                              PRSN_TYPE_LKP
# 4                             OCCPNT_POS_LKP

# %%
# Link between feature name and its coding sheet
link_u=pd.read_excel(xls,sheet_name='Unit File Specification',header=6,usecols=['Column Header','Description','Data Values with Valid Years if Applicable'])
link_u.head()
# Out:
#    Column Header                                        Description  \
# 0            NaN                          CR-3 Reported Data Fields
# 1       Crash_ID  Crash ID – System-generated unique identifying...
# 2       Unit_Nbr  Unit number entered on crash report for a unit...
# 3   Unit_Desc_ID     Unit Description  - Describes the type of unit
# 4  Veh_Parked_Fl                                     Parked Vehicle
#
#   Data Values with Valid Years if Applicable
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                          VEH_UNIT_DESC_LKP
# 4                          YES_NO_CHOICE_LKP

# %%
feats=df_final.columns

# %%
feats.shape
# Out:
# (39,)

# %%
# Combine all link
link_sheet=pd.concat([link_p,link_c,link_u]).reset_index(drop=True)
link_sheet=link_sheet[link_sheet['Column Header'].isin(feats)].reset_index(drop=True)
link_sheet
# Out:
#                Column Header  \
# 0                   Crash_ID
# 1                   Unit_Nbr
# 2               Prsn_Type_ID
# 3         Prsn_Occpnt_Pos_ID
# 4          Prsn_Injry_Sev_ID
# 5                   Prsn_Age
# 6          Prsn_Ethnicity_ID
# 7               Prsn_Gndr_ID
# 8               Prsn_Ejct_ID
# 9               Prsn_Rest_ID
# 10            Prsn_Airbag_ID
# 11            Prsn_Helmet_ID
# 12          Prsn_Drg_Rslt_ID
# 13                  Crash_ID
# 14                Crash_Date
# 15                Crash_Time
# 16           Rpt_Rdwy_Sys_ID
# 17          Rpt_Road_Part_ID
# 18              Toll_Road_Fl
# 19         Crash_Speed_Limit
# 20       Road_Constr_Zone_Fl
# 21  Road_Constr_Zone_Wrkr_Fl
# 22             At_Intrsct_Fl
# 23              Wthr_Cond_ID
# 24             Light_Cond_ID
# 25              Road_Algn_ID
# 26              Surf_Cond_ID
# 27           Traffic_Cntl_ID
# 28                  Latitude
# 29                 Longitude
# 30              Pop_Group_ID
# 31               Day_of_Week
# 32                  Crash_ID
# 33                  Unit_Nbr
# 34              Unit_Desc_ID
# 35             Veh_Parked_Fl
# 36                Veh_HNR_Fl
# 37              Veh_Mod_Year
# 38              Veh_Color_ID
# 39               Veh_Make_ID
# 40                Veh_Mod_ID
# 41          Veh_Body_Styl_ID
#
#                                           Description  \
# 0   Crash ID – System-generated unique identifying...
# 1   Unit number entered on crash report for a unit...
# 2                                         Person Type
# 3   The physical location of an occupant in, on, o...
# 4                  Severity of injury to the occupant
# 5                 Age of person involved in the crash
# 6           Ethnicity of person involved in the crash
# 7              Gender of person involved in the crash
# 8   The extent to which the person's body was expe...
# 9         The type of restraint used by each occupant
# 10  Indicates whether a person's airbag deployed d...
# 11  Indicates if a helmet was worn at the time of ...
# 12                    Primary person drug test result
# 13  Crash ID – System-generated unique identifying...
# 14          Crash Date - Date on which crash occurred
# 15                   Crash Time - Time crash occurred
# 16      Roadway System (road on which crash occurred)
# 17        Roadway Part (road on which crash occurred)
# 18                                Toll Road/Toll Lane
# 19                                        Speed Limit
# 20  Construction Zone - Indicates whether the cras...
# 21  Workers Present - Indicates whether workers we...
# 22  At Intersection - Indicates if the crash occur...
# 23  Weather Condition - The prevailing atmospheric...
# 24  Light Condition - The type and level of light ...
# 25  Roadway Alignment - The geometric characterist...
# 26  Surface Condition - The surface condition (wet...
# 27  Traffic Control - Type of traffic control at t...
# 28               Latitude map coordinate of the crash
# 29              Longitude map coordinate of the crash
# 30  Population Group - Population group of the loc...
# 31  Day of Week - The day of the week that the cra...
# 32  Crash ID – System-generated unique identifying...
# 33  Unit number entered on crash report for a unit...
# 34     Unit Description  - Describes the type of unit
# 35                                     Parked Vehicle
# 36                                        Hit and Run
# 37  4–digit numeric model year of the vehicle as d...
# 38                                      Vehicle Color
# 39  The vehicle manufacturer’s distinctive name ap...
# 40              The vehicle manufacturer’s trade name
# 41  The body style of the vehicle involved in the ...
#
#    Data Values with Valid Years if Applicable
# 0                                         NaN
# 1                                         NaN
# 2                               PRSN_TYPE_LKP
# 3                              OCCPNT_POS_LKP
# 4                               INJRY_SEV_LKP
# 5                                         NaN
# 6                            DRVR_ETHNCTY_LKP
# 7                                    GNDR_LKP
# 8                                    EJCT_LKP
# 9                                    REST_LKP
# 10                                 AIRBAG_LKP
# 11                                 HELMET_LKP
# 12                     SUBSTNC_TST_RESULT_LKP
# 13                                        NaN
# 14                                        NaN
# 15                                        NaN
# 16                                RWY_SYS_LKP
# 17                              ROAD_PART_LKP
# 18                          YES_NO_CHOICE_LKP
# 19                                        NaN
# 20                          YES_NO_CHOICE_LKP
# 21                          YES_NO_CHOICE_LKP
# 22                          YES_NO_CHOICE_LKP
# 23                              WTHR_COND_LKP
# 24                             LIGHT_COND_LKP
# 25                              ROAD_ALGN_LKP
# 26                              SURF_COND_LKP
# 27                           TRAFFIC_CNTL_LKP
# 28                                        NaN
# 29                                        NaN
# 30                              POP_GROUP_LKP
# 31                                        NaN
# 32                                        NaN
# 33                                        NaN
# 34                          VEH_UNIT_DESC_LKP
# 35                          YES_NO_CHOICE_LKP
# 36                          YES_NO_CHOICE_LKP
# 37                               VEH_YEAR_LKP
# 38                              VEH_COLOR_LKP
# 39                               VEH_MAKE_LKP
# 40                                VEH_MOD_LKP
# 41                          VEH_BODY_STYL_LKP

# %%
link_sheet.to_csv('Chosen features.csv',index=False)

# %%
df_final.drop(columns=['Crash_ID'],inplace=True)

# %%
df_final.dropna().to_csv('VCA data nomap.csv',index=False)
