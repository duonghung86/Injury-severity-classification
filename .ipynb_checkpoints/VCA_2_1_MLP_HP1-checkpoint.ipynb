# %% [markdown]
# <a href="https://colab.research.google.com/github/duonghung86/Injury-severity-classification/blob/main/VCA_2_1_MLP_earlystopping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from psutil import virtual_memory,cpu_percent
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))
print('Current system-wide CPU utilization %: ',cpu_percent())
#Remove all warning
import warnings
warnings.filterwarnings("ignore")
# Out:
# Your runtime has 270.0 gigabytes of available RAM
#
# Current system-wide CPU utilization %:  4.0

# %%
# Basic packages
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import time
import os
from collections import Counter
# Preprocessing
from sklearn.preprocessing import StandardScaler # Standardization
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# Machine learning algos
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
# Imblearn
from imblearn.metrics import geometric_mean_score
from imblearn.over_sampling import SMOTE, RandomOverSampler,BorderlineSMOTE
from imblearn.under_sampling import RandomUnderSampler,NearMiss,EditedNearestNeighbours

# Tensorflow
import tensorflow as tf
print(tf.__version__)
from tensorflow import feature_column  # for data wrangling
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.layers import Dense,Dropout, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.metrics import SparseCategoricalAccuracy
from tensorflow_addons.metrics import CohenKappa,F1Score
#Remove all warning
import warnings
warnings.filterwarnings("ignore")
# Out:
# 2.1.0

# %%
url = 'https://github.com/duonghung86/Injury-severity-classification/blob/main/Prepared%20Texas%202019.zip?raw=true' 
data_path = tf.keras.utils.get_file(origin=url, fname=url.split('/')[-1].split('?')[0], extract=True)
data_path = data_path.replace('%20',' ').replace('.zip','.csv')

# %%
# Load data
df = pd.read_csv(data_path)
print(df.shape)
df.head(3)
# Out:
# (949856, 19)
#    Prsn_Injry_Sev  Prsn_Age Prsn_Gndr Wthr_Cond Light_Cond Surf_Cond  \
# 0               0        26      MALE     CLEAR   DAYLIGHT       DRY
# 1               0        52      MALE     CLEAR   DAYLIGHT       DRY
# 2               0        27    FEMALE     CLEAR   DAYLIGHT       DRY
#
#            Veh_Body_Styl            Prsn_Rest   Prsn_Drg_Rslt  \
# 0  PASSENGER CAR, 2-DOOR  SHOULDER & LAP BELT  Not Applicable
# 1  PASSENGER CAR, 2-DOOR  SHOULDER & LAP BELT  Not Applicable
# 2                 PICKUP  SHOULDER & LAP BELT  Not Applicable
#
#                     Harm_Evnt  Rural  Crash_Speed_Limit        Road_Algn  \
# 0  MOTOR VEHICLE IN TRANSPORT      0                 -1  STRAIGHT, LEVEL
# 1  MOTOR VEHICLE IN TRANSPORT      0                 -1  STRAIGHT, LEVEL
# 2  MOTOR VEHICLE IN TRANSPORT      1                 -1     CURVE, LEVEL
#
#    Veh_Mod_Year  Weekend  Crash_season  Part_of_day     Collsn_type  \
# 0            33        1             3            3  SAME DIRECTION
# 1            19        1             3            3  SAME DIRECTION
# 2            16        1             3            4  SAME DIRECTION
#
#                   Collsn_name
# 0  ONE STRAIGHT-ONE LEFT TURN
# 1  ONE STRAIGHT-ONE LEFT TURN
# 2              BOTH LEFT TURN

# %%
# Let's just use 80% of the total dataset
#df, _ = train_test_split(df, test_size=0.9,stratify = df['Prsn_Injry_Sev'])
df.shape
# Out:
# (949856, 19)

# %%
y = df['Prsn_Injry_Sev']
print('All target values:')
print(y.value_counts())
X = df.drop(columns=['Prsn_Injry_Sev'])
# Out:
# All target values:
# 0    792558
# 1    102409
# 2     45242
# 3      7951
# 4      1696
# Name: Prsn_Injry_Sev, dtype: int64

# %%
# %% Data wrangling -------------
# Classify variable type
emb_vars, ind_vars, num_vars = [], [], []
for var in X.columns:
    if X[var].dtypes == 'O':
        if len(X[var].unique()) > 5:
            emb_vars.append(var)
        else:
            ind_vars.append(var)
    else:
        num_vars.append(var)
print('Numerical variables are ', num_vars)
print('Categorical variables that have at most 5 categories are ', ind_vars)
print('Categorical variables that have more than 5 categories are ', emb_vars)

# Create feature columns
feature_columns = []
# numeric cols
for header in num_vars:
    feature_columns.append(feature_column.numeric_column(header))
# bucketized cols
# age = feature_column.numeric_column('Prsn_Age')
# age_buckets = feature_column.bucketized_column(age, boundaries=[16, 22, 35, 55, 65])
# feature_columns.append(age_buckets)
# indicator_columns
for col_name in ind_vars:
    categorical_column = feature_column.categorical_column_with_vocabulary_list(
        col_name, X[col_name].unique())
    indicator_column = feature_column.indicator_column(categorical_column)
    feature_columns.append(indicator_column)
# embedding columns
for col_name in emb_vars:
    emb_column = feature_column.categorical_column_with_vocabulary_list(
        col_name, X[col_name].unique())
    col_embedding = feature_column.embedding_column(emb_column, dimension=5)
    feature_columns.append(col_embedding)

# Convert all setup into new dataset
feature_layer = tf.keras.layers.DenseFeatures(feature_columns)
X = feature_layer(dict(X)).numpy()
print('New shape of the input data set:',X.shape)
# Out:
# Numerical variables are  ['Prsn_Age', 'Rural', 'Crash_Speed_Limit', 'Veh_Mod_Year', 'Weekend', 'Crash_season', 'Part_of_day']
# Categorical variables that have at most 5 categories are  ['Prsn_Gndr', 'Prsn_Drg_Rslt', 'Collsn_type']
# Categorical variables that have more than 5 categories are  ['Wthr_Cond', 'Light_Cond', 'Surf_Cond', 'Veh_Body_Styl', 'Prsn_Rest', 'Harm_Evnt', 'Road_Algn', 'Collsn_name']
# WARNING:tensorflow:From /project/cacds/apps/easybuild/software/Anaconda3/5.0.1/lib/python3.6/site-packages/tensorflow_core/python/feature_column/feature_column_v2.py:4267: IndicatorColumn._variable_shape (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From /project/cacds/apps/easybuild/software/Anaconda3/5.0.1/lib/python3.6/site-packages/tensorflow_core/python/feature_column/feature_column_v2.py:4322: VocabularyListCategoricalColumn._num_buckets (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed in a future version.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# New shape of the input data set: (949856, 59)

# %%
# %% Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=48)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, stratify=y_train, random_state=48)

print('Training features shape:', X_train.shape)
print('Validation features shape:', X_val.shape)
print('Test features shape:', X_test.shape)

# %% standardization
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)
# Out:
# Training features shape: (607907, 59)
# Validation features shape: (151977, 59)
# Test features shape: (189972, 59)

# %% [markdown]
# # ALL mini functions

# %%
# Import Metrics
from imblearn.metrics import geometric_mean_score
from sklearn.metrics import roc_auc_score,confusion_matrix,accuracy_score

# %% Function to compare the prediction and true labels
def get_accs(label, pred_proba, tr_time=0,index=None):
    prediction = pred_proba.argmax(axis=1)
    cm = confusion_matrix(label, prediction)
    length = cm.shape[0]
    num_cases = len(label)
    # global accuracy
    glb_acc = np.trace(cm) / len(label)
    ind_accs = cm / np.sum(cm, axis=1)[:, np.newaxis]
    accs = [ind_accs[i, i] for i in range(length)]
    cols = ['Class {}'.format(i) for i in range(length)]
    # Global accuracy
    accs.append(glb_acc)
    # AUC
    accs.append(roc_auc_score(label, pred_proba,multi_class='ovr'))
    # G-mean
    accs.append(geometric_mean_score(label, prediction, correction=0.001))
    # Average perf
    accs.append(np.mean(accs[-3:]))
    # Training time
    accs.append(np.round(tr_time,3))
    cols = cols + ['Accuracy','AUC','G-mean','Avg_Pfm','Training Time']

    out = np.array(accs).reshape(1, len(accs))
    return pd.DataFrame(out, columns=cols,index=[index])

# %% [markdown]
# # ML with class weight

# %%
wgt='balanced'
clfs = [LogisticRegression(solver = 'lbfgs',class_weight=wgt),
        DecisionTreeClassifier(class_weight=wgt),
        RandomForestClassifier(max_depth=4,class_weight=wgt)]
clf_names = ['LR','DT','RF']
rsts = pd.DataFrame()
for model, name in zip(clfs,clf_names):
    start = time.time()
    print(name)
    model.fit(X_train, y_train.values)
    end= time.time()
    # use the model to make predictions with the test data
    Y_pred = model.predict_proba(X_test)

    # get the evaluation metrics
    rsts = rsts.append(get_accs(y_test.values,Y_pred,end-start,name))
print(rsts.iloc[:,5:])
# Out:
# LR
# DT
# RF
#          AUC    G-mean   Avg_Pfm  Training Time
# LR  0.711492  0.377954  0.526608         32.114
# DT  0.537141  0.156678  0.468967         10.894
# RF  0.679210  0.288530  0.495021         29.827

# %% [markdown]
# # MLP functions

# %%
# Add weights
weights = len(y) / (5 * np.bincount(y))
cls_wgt = dict(zip(np.arange(5), weights))
cls_wgt
# Out:
# {0: 0.23969375111979185,
#  1: 1.855024460740755,
#  2: 4.199000928340922,
#  3: 23.89274305118853,
#  4: 112.01132075471698}

# %%
def early_stops(metric_name):
    es = EarlyStopping(monitor='val_'+ metric_name,
                   verbose=1, patience=10, mode='max',
                   restore_best_weights=True)
    return es

# %%
# Constant
EPOCH = 50
BATCH_SIZE = 2048
VERBOSE = 0

# %%
def create_mlp():
    MLP = Sequential([Dense(10,
                           activation='relu',
                           input_dim=X_train.shape[1],
                           ),
                      BatchNormalization(),
                      Dropout(0.5),
                      Dense(5, activation='softmax')])
    MLP.compile(optimizer='adam',
                loss=SparseCategoricalCrossentropy(from_logits=True),
                metrics=[tf.keras.metrics.SparseCategoricalAccuracy(name='accuracy')]
               )
    return MLP

# %%
for i in range(3):
    model = create_mlp()
    start = time.time()
    monitor = model.fit(X_train, y_train.values,
                        callbacks=[early_stops('accuracy')],
                        class_weight = cls_wgt,
                        validation_data=(X_val, y_val.values),
                        batch_size=BATCH_SIZE,
                        verbose=VERBOSE, epochs=EPOCH
                       )
    end = time.time()
    # use the model to make predictions with the test data
    Y_pred = model.predict(X_test)
    rsts = rsts.append(get_accs(y_test.values,Y_pred,end-start,'MLP-W-#'+str(i+1)))
rsts
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 607907 samples, validate on 151977 samples
# Epoch 1/50
# 607907/607907 - 2s - loss: 1.5769 - accuracy: 0.2842 - val_loss: 1.5075 - val_accuracy: 0.3709
# Epoch 2/50
# 607907/607907 - 1s - loss: 1.5182 - accuracy: 0.3675 - val_loss: 1.4854 - val_accuracy: 0.4299
# Epoch 3/50
# 607907/607907 - 1s - loss: 1.5025 - accuracy: 0.4065 - val_loss: 1.4760 - val_accuracy: 0.4418
# Epoch 4/50
# 607907/607907 - 1s - loss: 1.4931 - accuracy: 0.4225 - val_loss: 1.4704 - val_accuracy: 0.4661
# Epoch 5/50
# 607907/607907 - 1s - loss: 1.4863 - accuracy: 0.4404 - val_loss: 1.4667 - val_accuracy: 0.4774
# Epoch 6/50
# 607907/607907 - 1s - loss: 1.4848 - accuracy: 0.4466 - val_loss: 1.4644 - val_accuracy: 0.4770
# Epoch 7/50
# 607907/607907 - 1s - loss: 1.4792 - accuracy: 0.4494 - val_loss: 1.4630 - val_accuracy: 0.4790
# Epoch 8/50
# 607907/607907 - 1s - loss: 1.4791 - accuracy: 0.4547 - val_loss: 1.4616 - val_accuracy: 0.4752
# Epoch 9/50
# 607907/607907 - 1s - loss: 1.4741 - accuracy: 0.4575 - val_loss: 1.4601 - val_accuracy: 0.4789
# Epoch 10/50
# 607907/607907 - 1s - loss: 1.4748 - accuracy: 0.4561 - val_loss: 1.4597 - val_accuracy: 0.4728
# Epoch 11/50
# 607907/607907 - 1s - loss: 1.4717 - accuracy: 0.4575 - val_loss: 1.4584 - val_accuracy: 0.4793
# Epoch 12/50
# 607907/607907 - 1s - loss: 1.4694 - accuracy: 0.4628 - val_loss: 1.4584 - val_accuracy: 0.4759
# Epoch 13/50
# 607907/607907 - 1s - loss: 1.4679 - accuracy: 0.4616 - val_loss: 1.4579 - val_accuracy: 0.4741
# Epoch 14/50
# 607907/607907 - 1s - loss: 1.4656 - accuracy: 0.4614 - val_loss: 1.4576 - val_accuracy: 0.4699
# Epoch 15/50
# 607907/607907 - 1s - loss: 1.4671 - accuracy: 0.4641 - val_loss: 1.4576 - val_accuracy: 0.4748
# Epoch 16/50
# 607907/607907 - 1s - loss: 1.4642 - accuracy: 0.4607 - val_loss: 1.4579 - val_accuracy: 0.4733
# Epoch 17/50
# 607907/607907 - 1s - loss: 1.4653 - accuracy: 0.4629 - val_loss: 1.4567 - val_accuracy: 0.4790
# Epoch 18/50
# 607907/607907 - 1s - loss: 1.4647 - accuracy: 0.4618 - val_loss: 1.4571 - val_accuracy: 0.4739
# Epoch 19/50
# 607907/607907 - 1s - loss: 1.4651 - accuracy: 0.4645 - val_loss: 1.4577 - val_accuracy: 0.4781
# Epoch 20/50
# 607907/607907 - 1s - loss: 1.4647 - accuracy: 0.4644 - val_loss: 1.4571 - val_accuracy: 0.4738
# Epoch 21/50
# Restoring model weights from the end of the best epoch.
# 607907/607907 - 1s - loss: 1.4625 - accuracy: 0.4657 - val_loss: 1.4581 - val_accuracy: 0.4728
# Epoch 00021: early stopping
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 607907 samples, validate on 151977 samples
# Epoch 1/50
# 607907/607907 - 2s - loss: 1.6076 - accuracy: 0.2887 - val_loss: 1.5410 - val_accuracy: 0.4630
# Epoch 2/50
# 607907/607907 - 1s - loss: 1.5435 - accuracy: 0.4254 - val_loss: 1.4923 - val_accuracy: 0.5238
# Epoch 3/50
# 607907/607907 - 1s - loss: 1.5136 - accuracy: 0.4695 - val_loss: 1.4758 - val_accuracy: 0.5121
# Epoch 4/50
# 607907/607907 - 1s - loss: 1.4989 - accuracy: 0.4788 - val_loss: 1.4673 - val_accuracy: 0.4986
# Epoch 5/50
# 607907/607907 - 1s - loss: 1.4901 - accuracy: 0.4708 - val_loss: 1.4632 - val_accuracy: 0.5039
# Epoch 6/50
# 607907/607907 - 1s - loss: 1.4835 - accuracy: 0.4723 - val_loss: 1.4603 - val_accuracy: 0.5107
# Epoch 7/50
# 607907/607907 - 1s - loss: 1.4785 - accuracy: 0.4686 - val_loss: 1.4585 - val_accuracy: 0.5111
# Epoch 8/50
# 607907/607907 - 1s - loss: 1.4756 - accuracy: 0.4736 - val_loss: 1.4584 - val_accuracy: 0.5033
# Epoch 9/50
# 607907/607907 - 1s - loss: 1.4750 - accuracy: 0.4684 - val_loss: 1.4574 - val_accuracy: 0.4989
# Epoch 10/50
# 607907/607907 - 1s - loss: 1.4708 - accuracy: 0.4737 - val_loss: 1.4567 - val_accuracy: 0.5040
# Epoch 11/50
# 607907/607907 - 1s - loss: 1.4719 - accuracy: 0.4732 - val_loss: 1.4574 - val_accuracy: 0.5041
# Epoch 12/50
# Restoring model weights from the end of the best epoch.
# 607907/607907 - 1s - loss: 1.4709 - accuracy: 0.4748 - val_loss: 1.4565 - val_accuracy: 0.5026
# Epoch 00012: early stopping
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 607907 samples, validate on 151977 samples
# Epoch 1/50
# 607907/607907 - 2s - loss: 1.6127 - accuracy: 0.2762 - val_loss: 1.5366 - val_accuracy: 0.3458
# Epoch 2/50
# 607907/607907 - 1s - loss: 1.5359 - accuracy: 0.3849 - val_loss: 1.4909 - val_accuracy: 0.4298
# Epoch 3/50
# 607907/607907 - 1s - loss: 1.5079 - accuracy: 0.4481 - val_loss: 1.4777 - val_accuracy: 0.4824
# Epoch 4/50
# 607907/607907 - 1s - loss: 1.5010 - accuracy: 0.4721 - val_loss: 1.4711 - val_accuracy: 0.4980
# Epoch 5/50
# 607907/607907 - 1s - loss: 1.4932 - accuracy: 0.4789 - val_loss: 1.4665 - val_accuracy: 0.5048
# Epoch 6/50
# 607907/607907 - 1s - loss: 1.4886 - accuracy: 0.4832 - val_loss: 1.4642 - val_accuracy: 0.5030
# Epoch 7/50
# 607907/607907 - 1s - loss: 1.4799 - accuracy: 0.4804 - val_loss: 1.4619 - val_accuracy: 0.5099
# Epoch 8/50
# 607907/607907 - 1s - loss: 1.4802 - accuracy: 0.4823 - val_loss: 1.4602 - val_accuracy: 0.4998
# Epoch 9/50
# 607907/607907 - 1s - loss: 1.4744 - accuracy: 0.4820 - val_loss: 1.4591 - val_accuracy: 0.5128
# Epoch 10/50
# 607907/607907 - 1s - loss: 1.4735 - accuracy: 0.4814 - val_loss: 1.4588 - val_accuracy: 0.5003
# Epoch 11/50
# 607907/607907 - 1s - loss: 1.4728 - accuracy: 0.4749 - val_loss: 1.4587 - val_accuracy: 0.5003
# Epoch 12/50
# 607907/607907 - 1s - loss: 1.4702 - accuracy: 0.4794 - val_loss: 1.4578 - val_accuracy: 0.4897
# Epoch 13/50
# 607907/607907 - 1s - loss: 1.4687 - accuracy: 0.4743 - val_loss: 1.4583 - val_accuracy: 0.4851
# Epoch 14/50
# 607907/607907 - 1s - loss: 1.4708 - accuracy: 0.4726 - val_loss: 1.4579 - val_accuracy: 0.4867
# Epoch 15/50
# 607907/607907 - 1s - loss: 1.4680 - accuracy: 0.4750 - val_loss: 1.4571 - val_accuracy: 0.5002
# Epoch 16/50
# 607907/607907 - 1s - loss: 1.4677 - accuracy: 0.4792 - val_loss: 1.4570 - val_accuracy: 0.5025
# Epoch 17/50
# 607907/607907 - 1s - loss: 1.4674 - accuracy: 0.4739 - val_loss: 1.4570 - val_accuracy: 0.4831
# Epoch 18/50
# 607907/607907 - 1s - loss: 1.4669 - accuracy: 0.4703 - val_loss: 1.4577 - val_accuracy: 0.4820
# Epoch 19/50
# Restoring model weights from the end of the best epoch.
# 607907/607907 - 1s - loss: 1.4663 - accuracy: 0.4718 - val_loss: 1.4573 - val_accuracy: 0.4848
# Epoch 00019: early stopping
#            Class 0   Class 1   Class 2   Class 3   Class 4  Accuracy  \
# LR        0.520099  0.421736  0.140015  0.362264  0.693215  0.490378
# DT        0.829786  0.146909  0.086971  0.047170  0.188791  0.713084
# RF        0.557737  0.429011  0.038899  0.312579  0.687316  0.517324
# MLP-W-#1  0.502183  0.471829  0.109183  0.259119  0.728614  0.478560
# MLP-W-#2  0.594718  0.201543  0.058570  0.298113  0.758112  0.524598
# MLP-W-#3  0.550085  0.419539  0.101448  0.258491  0.761062  0.512576
#
#                AUC    G-mean   Avg_Pfm  Training Time
# LR        0.711492  0.377954  0.526608         32.114
# DT        0.537141  0.156678  0.468967         10.894
# RF        0.679210  0.288530  0.495021         29.827
# MLP-W-#1  0.690777  0.344953  0.504763         20.790
# MLP-W-#2  0.676843  0.275482  0.492308         12.264
# MLP-W-#3  0.696551  0.340927  0.516685         18.845

# %% [markdown]
# # Hybrid Resampling

# %%
y_dict = Counter(y_train)

start = time.time()
res = RandomUnderSampler(random_state = 54, sampling_strategy={0: y_dict[1]})
print('under sampling ...')
X_res, y_res = res.fit_resample(X_train, y_train)

res = SMOTE(random_state = 34,sampling_strategy='not majority')
print(Counter(y_res))
print('over sampling #2 ...')
X_res, y_res = res.fit_resample(X_res, y_res)
end = time.time()
res_time = end-start
Counter(y_res),res_time
# Out:
# under sampling ...
# Counter({0: 65541, 1: 65541, 2: 28954, 3: 5089, 4: 1086})
# over sampling #2 ...
# (Counter({0: 65541, 1: 65541, 2: 65541, 3: 65541, 4: 65541}),
#  68.27833485603333)

# %% [markdown]
# # MLP with Hybrid Sampling

# %%
for i in range(3):
    model = create_mlp()
    start = time.time()
    monitor = model.fit(X_res, y_res,
                        callbacks=[early_stops('accuracy')],
                        validation_data=(X_val, y_val.values),
                        batch_size=BATCH_SIZE,
                        verbose=VERBOSE, epochs=EPOCH
                       )
    end = time.time()
    # use the model to make predictions with the test data
    Y_pred = model.predict(X_test)
    rsts = rsts.append(get_accs(y_test.values,Y_pred,end-start,'MLP-HS#'+str(i+1)))
rsts
# Out:
# Restoring model weights from the end of the best epoch.
# Epoch 00013: early stopping
# Restoring model weights from the end of the best epoch.
# Epoch 00012: early stopping
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping
#            Class 0   Class 1   Class 2   Class 3   Class 4  Accuracy  \
# LR        0.520099  0.421736  0.140015  0.362264  0.693215  0.490378
# DT        0.829786  0.146909  0.086971  0.047170  0.188791  0.713084
# RF        0.557737  0.429011  0.038899  0.312579  0.687316  0.517324
# MLP-W-#1  0.502183  0.471829  0.109183  0.259119  0.728614  0.478560
# MLP-W-#2  0.594718  0.201543  0.058570  0.298113  0.758112  0.524598
# MLP-W-#3  0.550085  0.419539  0.101448  0.258491  0.761062  0.512576
# MLP-HS#1  0.595034  0.337955  0.116366  0.250943  0.772861  0.541954
# MLP-HS#2  0.613083  0.187579  0.209305  0.238994  0.775811  0.545133
# MLP-HS#3  0.619259  0.184943  0.016134  0.216352  0.820059  0.540690
#
#                AUC    G-mean   Avg_Pfm  Training Time
# LR        0.711492  0.377954  0.526608         32.114
# DT        0.537141  0.156678  0.468967         10.894
# RF        0.679210  0.288530  0.495021         29.827
# MLP-W-#1  0.690777  0.344953  0.504763         20.790
# MLP-W-#2  0.676843  0.275482  0.492308         12.264
# MLP-W-#3  0.696551  0.340927  0.516685         18.845
# MLP-HS#1  0.692058  0.339924  0.524645          7.577
# MLP-HS#2  0.683803  0.338786  0.522574          7.026
# MLP-HS#3  0.637569  0.200971  0.459744          6.398

# %% [markdown]
# ## Set up initial weights

# %%
np.bincount(y)
# Out:
# array([79255, 10241,  4524,   795,   170])

# %%
initial_bias = np.log([np.bincount(y)[-1]/np.bincount(y)[0]])
initial_bias
# Out:
# array([-6.14462734])

# %%
tf.keras.initializers.VarianceScaling(
    scale=1.0, mode="fan_in", distribution="truncated_normal", seed=None
)

# %%
from tensorflow.keras.initializers import RandomNormal,VarianceScaling

# %%
he_ini = tf.keras.initializers.VarianceScaling(scale=2, mode='fan_in', distribution='normal',seed=35)

# %% [markdown]
# # Ordinal multiclass

# %%
early_stop = {'accuracy':  tf.keras.metrics.SparseCategoricalAccuracy(name='accuracy'),
              'cohen_kappa': CohenKappa(num_classes=5,sparse_labels=True),
              'f1_score': F1Score(num_classes=5,average="micro",threshold=0.5),
               }

# %%
def create_mlp(metric):
    MLP = Sequential([Dense(10,
                           activation='relu',
                           input_dim=X_train.shape[1],
                            kernel_initializer=he_ini,
                           ),
                        BatchNormalization(),
                      Dropout(0.5),
                      Dense(5, activation='softmax')])
    MLP.compile(optimizer='adam',
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                #loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
                metrics=[metric]
               )
    return MLP

# %%
for name, metric in early_stop.items():
    print(name)
    model = create_mlp(metric)
    start = time.time()
    monitor = model.fit(X_train, y_train.values,
                    callbacks=[early_stops(name)],
                    class_weight = cls_wgt,
                    validation_data=(X_val, y_val.values),
                    batch_size=BATCH_SIZE,
                verbose=1, epochs=EPOCH)
    end = time.time()
    rsts = rsts.append(evaluation(model, monitor, end - start,  'MLP '+ name))
print(rsts.iloc[:,-4:])
# Out:
# accuracy
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 60790 samples, validate on 15198 samples
# Epoch 1/50
# 60790/60790 [==============================] - 1s 12us/sample - loss: 1.6383 - accuracy: 0.1609 - val_loss: 1.6284 - val_accuracy: 0.3591
# Epoch 2/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.6313 - accuracy: 0.1637 - val_loss: 1.6212 - val_accuracy: 0.3357
# Epoch 3/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.6253 - accuracy: 0.1691 - val_loss: 1.6131 - val_accuracy: 0.3106
# Epoch 4/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.6121 - accuracy: 0.1685 - val_loss: 1.6062 - val_accuracy: 0.2833
# Epoch 5/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.6054 - accuracy: 0.1722 - val_loss: 1.5990 - val_accuracy: 0.2612
# Epoch 6/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.6018 - accuracy: 0.1742 - val_loss: 1.5910 - val_accuracy: 0.2488
# Epoch 7/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5856 - accuracy: 0.1753 - val_loss: 1.5762 - val_accuracy: 0.2405
# Epoch 8/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5783 - accuracy: 0.1816 - val_loss: 1.5650 - val_accuracy: 0.2402
# Epoch 9/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5712 - accuracy: 0.1842 - val_loss: 1.5453 - val_accuracy: 0.2300
# Epoch 10/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5557 - accuracy: 0.1876 - val_loss: 1.5238 - val_accuracy: 0.2297
# Epoch 11/50
# 40960/60790 [===================>..........] - ETA: 0s - loss: 1.5626 - accuracy: 0.1925Restoring model weights from the end of the best epoch.
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5496 - accuracy: 0.1922 - val_loss: 1.5084 - val_accuracy: 0.2287
# Epoch 00011: early stopping
# cohen_kappa
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 60790 samples, validate on 15198 samples
# Epoch 1/50
# 60790/60790 [==============================] - 1s 18us/sample - loss: 1.6442 - cohen_kappa: -0.0032 - val_loss: 1.6142 - val_cohen_kappa: -0.0048
# Epoch 2/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.6183 - cohen_kappa: 0.0029 - val_loss: 1.5872 - val_cohen_kappa: 4.0805e-04
# Epoch 3/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.6167 - cohen_kappa: 0.0050 - val_loss: 1.5722 - val_cohen_kappa: 0.0083
# Epoch 4/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.6015 - cohen_kappa: 0.0094 - val_loss: 1.5587 - val_cohen_kappa: 0.0131
# Epoch 5/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5786 - cohen_kappa: 0.0116 - val_loss: 1.5493 - val_cohen_kappa: 0.0167
# Epoch 6/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5989 - cohen_kappa: 0.0104 - val_loss: 1.5392 - val_cohen_kappa: 0.0170
# Epoch 7/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5669 - cohen_kappa: 0.0148 - val_loss: 1.5269 - val_cohen_kappa: 0.0231
# Epoch 8/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5596 - cohen_kappa: 0.0170 - val_loss: 1.5183 - val_cohen_kappa: 0.0270
# Epoch 9/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5566 - cohen_kappa: 0.0209 - val_loss: 1.5089 - val_cohen_kappa: 0.0312
# Epoch 10/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5465 - cohen_kappa: 0.0241 - val_loss: 1.5043 - val_cohen_kappa: 0.0363
# Epoch 11/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5402 - cohen_kappa: 0.0250 - val_loss: 1.5007 - val_cohen_kappa: 0.0382
# Epoch 12/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5425 - cohen_kappa: 0.0266 - val_loss: 1.4965 - val_cohen_kappa: 0.0424
# Epoch 13/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5405 - cohen_kappa: 0.0330 - val_loss: 1.4928 - val_cohen_kappa: 0.0459
# Epoch 14/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5286 - cohen_kappa: 0.0312 - val_loss: 1.4906 - val_cohen_kappa: 0.0510
# Epoch 15/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5235 - cohen_kappa: 0.0329 - val_loss: 1.4860 - val_cohen_kappa: 0.0512
# Epoch 16/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5169 - cohen_kappa: 0.0381 - val_loss: 1.4821 - val_cohen_kappa: 0.0545
# Epoch 17/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5212 - cohen_kappa: 0.0401 - val_loss: 1.4797 - val_cohen_kappa: 0.0585
# Epoch 18/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5119 - cohen_kappa: 0.0421 - val_loss: 1.4778 - val_cohen_kappa: 0.0600
# Epoch 19/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5085 - cohen_kappa: 0.0394 - val_loss: 1.4772 - val_cohen_kappa: 0.0597
# Epoch 20/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5126 - cohen_kappa: 0.0403 - val_loss: 1.4753 - val_cohen_kappa: 0.0619
# Epoch 21/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5159 - cohen_kappa: 0.0468 - val_loss: 1.4739 - val_cohen_kappa: 0.0653
# Epoch 22/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5116 - cohen_kappa: 0.0452 - val_loss: 1.4724 - val_cohen_kappa: 0.0653
# Epoch 23/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4959 - cohen_kappa: 0.0440 - val_loss: 1.4713 - val_cohen_kappa: 0.0671
# Epoch 24/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4935 - cohen_kappa: 0.0491 - val_loss: 1.4710 - val_cohen_kappa: 0.0664
# Epoch 25/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4991 - cohen_kappa: 0.0454 - val_loss: 1.4697 - val_cohen_kappa: 0.0673
# Epoch 26/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5050 - cohen_kappa: 0.0480 - val_loss: 1.4688 - val_cohen_kappa: 0.0693
# Epoch 27/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4918 - cohen_kappa: 0.0479 - val_loss: 1.4682 - val_cohen_kappa: 0.0710
# Epoch 28/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4887 - cohen_kappa: 0.0524 - val_loss: 1.4677 - val_cohen_kappa: 0.0740
# Epoch 29/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4860 - cohen_kappa: 0.0522 - val_loss: 1.4661 - val_cohen_kappa: 0.0745
# Epoch 30/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4909 - cohen_kappa: 0.0536 - val_loss: 1.4656 - val_cohen_kappa: 0.0754
# Epoch 31/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4908 - cohen_kappa: 0.0561 - val_loss: 1.4649 - val_cohen_kappa: 0.0749
# Epoch 32/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4826 - cohen_kappa: 0.0560 - val_loss: 1.4640 - val_cohen_kappa: 0.0759
# Epoch 33/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4884 - cohen_kappa: 0.0548 - val_loss: 1.4625 - val_cohen_kappa: 0.0756
# Epoch 34/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4799 - cohen_kappa: 0.0595 - val_loss: 1.4628 - val_cohen_kappa: 0.0766
# Epoch 35/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4891 - cohen_kappa: 0.0578 - val_loss: 1.4631 - val_cohen_kappa: 0.0768
# Epoch 36/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4819 - cohen_kappa: 0.0573 - val_loss: 1.4624 - val_cohen_kappa: 0.0754
# Epoch 37/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4806 - cohen_kappa: 0.0593 - val_loss: 1.4612 - val_cohen_kappa: 0.0780
# Epoch 38/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4817 - cohen_kappa: 0.0612 - val_loss: 1.4604 - val_cohen_kappa: 0.0779
# Epoch 39/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4739 - cohen_kappa: 0.0628 - val_loss: 1.4601 - val_cohen_kappa: 0.0788
# Epoch 40/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4849 - cohen_kappa: 0.0604 - val_loss: 1.4603 - val_cohen_kappa: 0.0800
# Epoch 41/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4829 - cohen_kappa: 0.0636 - val_loss: 1.4607 - val_cohen_kappa: 0.0808
# Epoch 42/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4772 - cohen_kappa: 0.0652 - val_loss: 1.4600 - val_cohen_kappa: 0.0805
# Epoch 43/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4724 - cohen_kappa: 0.0646 - val_loss: 1.4594 - val_cohen_kappa: 0.0825
# Epoch 44/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4713 - cohen_kappa: 0.0669 - val_loss: 1.4592 - val_cohen_kappa: 0.0821
# Epoch 45/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4766 - cohen_kappa: 0.0679 - val_loss: 1.4585 - val_cohen_kappa: 0.0822
# Epoch 46/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4764 - cohen_kappa: 0.0683 - val_loss: 1.4568 - val_cohen_kappa: 0.0829
# Epoch 47/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4665 - cohen_kappa: 0.0668 - val_loss: 1.4572 - val_cohen_kappa: 0.0807
# Epoch 48/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4692 - cohen_kappa: 0.0686 - val_loss: 1.4567 - val_cohen_kappa: 0.0804
# Epoch 49/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4664 - cohen_kappa: 0.0703 - val_loss: 1.4587 - val_cohen_kappa: 0.0827
# Epoch 50/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4676 - cohen_kappa: 0.0686 - val_loss: 1.4592 - val_cohen_kappa: 0.0837
# f1_score
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 60790 samples, validate on 15198 samples
# Epoch 1/50
# 60790/60790 [==============================] - 1s 13us/sample - loss: 1.6471 - f1_score: 0.1081 - val_loss: 1.6218 - val_f1_score: 0.0906
# Epoch 2/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.6227 - f1_score: 0.1027 - val_loss: 1.6061 - val_f1_score: 0.0828
# Epoch 3/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.6100 - f1_score: 0.1004 - val_loss: 1.5929 - val_f1_score: 0.0746
# Epoch 4/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.6004 - f1_score: 0.0988 - val_loss: 1.5795 - val_f1_score: 0.0745
# Epoch 5/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5819 - f1_score: 0.0988 - val_loss: 1.5667 - val_f1_score: 0.0750
# Epoch 6/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5867 - f1_score: 0.0968 - val_loss: 1.5569 - val_f1_score: 0.0776
# Epoch 7/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5767 - f1_score: 0.1013 - val_loss: 1.5433 - val_f1_score: 0.0799
# Epoch 8/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5747 - f1_score: 0.1004 - val_loss: 1.5287 - val_f1_score: 0.0811
# Epoch 9/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5598 - f1_score: 0.1004 - val_loss: 1.5164 - val_f1_score: 0.0833
# Epoch 10/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5462 - f1_score: 0.1023 - val_loss: 1.5077 - val_f1_score: 0.0868
# Epoch 11/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5555 - f1_score: 0.1056 - val_loss: 1.4975 - val_f1_score: 0.0911
# Epoch 12/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5386 - f1_score: 0.1052 - val_loss: 1.4893 - val_f1_score: 0.0945
# Epoch 13/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5285 - f1_score: 0.1098 - val_loss: 1.4784 - val_f1_score: 0.0992
# Epoch 14/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5309 - f1_score: 0.1080 - val_loss: 1.4730 - val_f1_score: 0.1034
# Epoch 15/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5266 - f1_score: 0.1107 - val_loss: 1.4707 - val_f1_score: 0.1075
# Epoch 16/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5237 - f1_score: 0.1119 - val_loss: 1.4698 - val_f1_score: 0.1081
# Epoch 17/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5178 - f1_score: 0.1122 - val_loss: 1.4674 - val_f1_score: 0.1112
# Epoch 18/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.5052 - f1_score: 0.1124 - val_loss: 1.4633 - val_f1_score: 0.1161
# Epoch 19/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4965 - f1_score: 0.1164 - val_loss: 1.4583 - val_f1_score: 0.1207
# Epoch 20/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4988 - f1_score: 0.1175 - val_loss: 1.4569 - val_f1_score: 0.1242
# Epoch 21/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4935 - f1_score: 0.1186 - val_loss: 1.4562 - val_f1_score: 0.1257
# Epoch 22/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4947 - f1_score: 0.1193 - val_loss: 1.4561 - val_f1_score: 0.1286
# Epoch 23/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4878 - f1_score: 0.1200 - val_loss: 1.4559 - val_f1_score: 0.1310
# Epoch 24/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4901 - f1_score: 0.1201 - val_loss: 1.4542 - val_f1_score: 0.1308
# Epoch 25/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4895 - f1_score: 0.1205 - val_loss: 1.4538 - val_f1_score: 0.1319
# Epoch 26/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4866 - f1_score: 0.1211 - val_loss: 1.4533 - val_f1_score: 0.1342
# Epoch 27/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4932 - f1_score: 0.1213 - val_loss: 1.4521 - val_f1_score: 0.1355
# Epoch 28/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4913 - f1_score: 0.1226 - val_loss: 1.4514 - val_f1_score: 0.1350
# Epoch 29/50
# 60790/60790 [==============================] - ETA: 0s - loss: 1.4318 - f1_score: 0.12 - 0s 2us/sample - loss: 1.4817 - f1_score: 0.1248 - val_loss: 1.4504 - val_f1_score: 0.1377
# Epoch 30/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4844 - f1_score: 0.1246 - val_loss: 1.4502 - val_f1_score: 0.1378
# Epoch 31/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4771 - f1_score: 0.1261 - val_loss: 1.4491 - val_f1_score: 0.1395
# Epoch 32/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4809 - f1_score: 0.1255 - val_loss: 1.4491 - val_f1_score: 0.1393
# Epoch 33/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4767 - f1_score: 0.1258 - val_loss: 1.4493 - val_f1_score: 0.1385
# Epoch 34/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4772 - f1_score: 0.1251 - val_loss: 1.4492 - val_f1_score: 0.1378
# Epoch 35/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4887 - f1_score: 0.1269 - val_loss: 1.4482 - val_f1_score: 0.1381
# Epoch 36/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4763 - f1_score: 0.1264 - val_loss: 1.4479 - val_f1_score: 0.1360
# Epoch 37/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4812 - f1_score: 0.1280 - val_loss: 1.4480 - val_f1_score: 0.1344
# Epoch 38/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4659 - f1_score: 0.1263 - val_loss: 1.4476 - val_f1_score: 0.1359
# Epoch 39/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4778 - f1_score: 0.1269 - val_loss: 1.4468 - val_f1_score: 0.1353
# Epoch 40/50
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4709 - f1_score: 0.1274 - val_loss: 1.4467 - val_f1_score: 0.1356
# Epoch 41/50
# 38912/60790 [==================>...........] - ETA: 0s - loss: 1.4488 - f1_score: 0.1269Restoring model weights from the end of the best epoch.
# 60790/60790 [==============================] - 0s 2us/sample - loss: 1.4754 - f1_score: 0.1271 - val_loss: 1.4469 - val_f1_score: 0.1352
# Epoch 00041: early stopping
#                           Overall Accuracy    G-mean   Avg_Pfm  Training Time
# LR                                0.483182  0.379395  0.431289          4.191
# DT                                0.713534  0.158494  0.436014          0.845
# RF                                0.526504  0.322133  0.424318          2.275
# MLP-test RF                       0.452756  0.277340  0.365048          6.187
# MLP-test-no batch RF              0.506606  0.280187  0.393397          6.116
# MLP-test-large batch RF           0.321788  0.236041  0.278914          0.754
# MLP-test-medium batch RF          0.057272  0.181659  0.119465          0.856
# MLP-test-ki-rnRF                  0.322577  0.228207  0.275392          0.866
# MLP-test-ki-heRF                  0.156498  0.223777  0.190138          0.919
# MLP-test-ki-heRF                  0.208717  0.177501  0.193109          0.724
# MLP-test-ki-heRF                  0.468495  0.208918  0.338707          2.314
# MLP-test-ki-heRF                  0.498868  0.231079  0.364973          3.172
# MLP-test-ki-rnRF                  0.482813  0.258748  0.370781          2.074
# MLP-test                          0.483603  0.328978  0.406291          4.779
# MLP-test-ki-un                    0.490814  0.273104  0.381959          4.801
# MLP-test-ki-un-bn                 0.528557  0.319895  0.424226          5.773
# MLP-test-ki-un-bn2                0.572564  0.296205  0.434385          4.687
# MLP-test-ki-un-bn2                0.500079  0.316967  0.408523          4.293
# MLP-test-ki-un-bn2                0.543560  0.318264  0.430912          5.848
# MLP-test-ki-rn-bn2                0.474759  0.349274  0.412016          5.823
# MLP-test-ki-rn-bn2                0.469390  0.281504  0.375447          3.629
# MLP-test                          0.503185  0.244902  0.374043          3.609
# MLP accuracy                      0.353477  0.157308  0.255392          1.837
# MLP cohen_kappa                   0.505027  0.294999  0.400013          6.124
# MLP f1_score                      0.427646  0.314222  0.370934          4.976

# %% [markdown]
# # One-hot encoded multiclass

# %%
 early_stop = {'auc':       tf.keras.metrics.AUC(name='auc'),
     'accuracy':  tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
               'precision': tf.keras.metrics.Precision(name='precision'),
               'recall':    tf.keras.metrics.Recall(name='recall'),
               
               }

# %%
def create_mlp(metric):
    MLP = Sequential([Dense(10,
                           activation='relu',
                           input_dim=X_train.shape[1],
                            kernel_initializer=he_ini,
                           ),
                        BatchNormalization(),
                      Dropout(0.5),
                      Dense(5, activation='softmax')])
    MLP.compile(optimizer='adam',
                #loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
                metrics=[metric]
               )
    return MLP

# %%
#rsts = rsts.iloc[:6,:].copy()

# %%
for name, metric in early_stop.items():
    print(name)
    model = create_mlp(metric)
    start = time.time()
    monitor = model.fit(X_train, pd.get_dummies(y_train).values,
                    callbacks=[early_stops(name)],
                    class_weight = cls_wgt,
                    validation_data=(X_val, pd.get_dummies(y_val).values),
                    batch_size=BATCH_SIZE,
                    verbose=0, epochs=EPOCH)
    end = time.time()
    rsts = rsts.append(evaluation(model, monitor, end - start,  'MLP 1H '+ name))
print(rsts.iloc[:,-4:])
# Out:
# auc
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# accuracy
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# precision
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Restoring model weights from the end of the best epoch.
# Epoch 00039: early stopping
# recall
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
#                           Overall Accuracy    G-mean   Avg_Pfm  Training Time
# LR                                0.483182  0.379395  0.431289          4.191
# DT                                0.713534  0.158494  0.436014          0.845
# RF                                0.526504  0.322133  0.424318          2.275
# MLP-test RF                       0.452756  0.277340  0.365048          6.187
# MLP-test-no batch RF              0.506606  0.280187  0.393397          6.116
# MLP-test-large batch RF           0.321788  0.236041  0.278914          0.754
# MLP-test-medium batch RF          0.057272  0.181659  0.119465          0.856
# MLP-test-ki-rnRF                  0.322577  0.228207  0.275392          0.866
# MLP-test-ki-heRF                  0.156498  0.223777  0.190138          0.919
# MLP-test-ki-heRF                  0.208717  0.177501  0.193109          0.724
# MLP-test-ki-heRF                  0.468495  0.208918  0.338707          2.314
# MLP-test-ki-heRF                  0.498868  0.231079  0.364973          3.172
# MLP-test-ki-rnRF                  0.482813  0.258748  0.370781          2.074
# MLP-test                          0.483603  0.328978  0.406291          4.779
# MLP-test-ki-un                    0.490814  0.273104  0.381959          4.801
# MLP-test-ki-un-bn                 0.528557  0.319895  0.424226          5.773
# MLP-test-ki-un-bn2                0.572564  0.296205  0.434385          4.687
# MLP-test-ki-un-bn2                0.500079  0.316967  0.408523          4.293
# MLP-test-ki-un-bn2                0.543560  0.318264  0.430912          5.848
# MLP-test-ki-rn-bn2                0.474759  0.349274  0.412016          5.823
# MLP-test-ki-rn-bn2                0.469390  0.281504  0.375447          3.629
# MLP-test                          0.503185  0.244902  0.374043          3.609
# MLP accuracy                      0.353477  0.157308  0.255392          1.837
# MLP cohen_kappa                   0.505027  0.294999  0.400013          6.124
# MLP f1_score                      0.427646  0.314222  0.370934          4.976
# MLP 1H auc                        0.494604  0.304122  0.399363         13.306
# MLP 1H accuracy                   0.489393  0.301304  0.395348          5.651
# MLP 1H precision                  0.463073  0.284157  0.373615          5.093
# MLP 1H recall                     0.491551  0.311303  0.401427          5.872

# %%
rsts.to_csv('VCA_Early_stopping.csv')
